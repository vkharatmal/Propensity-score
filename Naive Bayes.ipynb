# %%
import pandas as pd

# %%
df=pd.read_csv('Product Training and Testing.csv')

# %%
df
# Out:
#         Identifier  Product Selection  Product_Activation  R_rank_norm  \
# 0           110354                  1                   0           34
# 1           110355                  1                   0           83
# 2           110357                  1                   0           62
# 3           110358                  1                   0           85
# 4           110359                  1                   0           58
# ...            ...                ...                 ...          ...
# 689048      793921                  1                   1           33
# 689049      793940                  1                   1           26
# 689050      794004                  1                   1           23
# 689051      794013                  1                   1           17
# 689052      794017                  1                   1            2
#
#         F_rank_norm  M_rank_norm  M2_rank_norm  RFM_Score  RFM2_Score  \
# ...

# %%
sns.displot(df.R_rank_norm)
